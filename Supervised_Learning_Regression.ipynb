# %% [markdown]
# # Supervised Learning: Regression Models and Performance Metrics
#
# ---

# %% [markdown]
# ## Question 1
# **What is Simple Linear Regression (SLR)? Explain its purpose.**
#
# **Answer:**
# Simple Linear Regression (SLR) is a statistical method used to model the relationship between one independent variable (X) and one dependent variable (Y) by fitting a straight line to observed data. Its purpose is to understand how changes in the independent variable affect the dependent variable and to make predictions.

# %% [markdown]
# ## Question 2
# **What are the key assumptions of Simple Linear Regression?**
#
# **Answer:**
# 1. Linearity
# 2. Independence of errors
# 3. Homoscedasticity
# 4. Normality of errors
# 5. No multicollinearity

# %% [markdown]
# ## Question 3
# **Write the mathematical equation for a simple linear regression model and explain each term.**
#
# **Answer:**
# Y = β₀ + β₁X + ε
#
# Where:
# - Y: Dependent variable
# - X: Independent variable
# - β₀: Intercept
# - β₁: Slope
# - ε: Error term

# %% [markdown]
# ## Question 4
# **Provide a real-world example where simple linear regression can be applied.**
#
# **Answer:**
# Predicting house prices based on the size of the house in square feet.

# %% [markdown]
# ## Question 5
# **What is the method of least squares in linear regression?**
#
# **Answer:**
# The method of least squares estimates regression coefficients by minimizing the sum of squared differences between actual and predicted values.

# %% [markdown]
# ## Question 6
# **What is Logistic Regression? How does it differ from Linear Regression?**
#
# **Answer:**
# Logistic Regression is used for binary classification problems and outputs probabilities using the sigmoid function, whereas Linear Regression predicts continuous values.

# %% [markdown]
# ## Question 7
# **Name and briefly describe three common evaluation metrics for regression models.**
#
# **Answer:**
# 1. Mean Absolute Error (MAE): Average absolute errors
# 2. Mean Squared Error (MSE): Average squared errors
# 3. R-squared: Variance explained by the model

# %% [markdown]
# ## Question 8
# **What is the purpose of the R-squared metric in regression analysis?**
#
# **Answer:**
# R-squared measures how well the independent variable explains the variance in the dependent variable.

# %%
# Question 9
# Write Python code to fit a simple linear regression model using scikit-learn
from sklearn.linear_model import LinearRegression
import numpy as np

X = np.array([[1],[2],[3],[4],[5]])
y = np.array([2,4,5,4,5])

model = LinearRegression()
model.fit(X, y)

print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope: 0.6000000000000002
# Intercept: 2.1999999999999993

# %% [markdown]
# ## Question 10
# **How do you interpret the coefficients in a simple linear regression model?**
#
# **Answer:**
# The slope represents the change in the dependent variable for a one-unit change in the independent variable. The intercept represents the value of the dependent variable when the independent variable is zero.
