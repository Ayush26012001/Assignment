# %%
1. What is a parameter?
A parameter is a variable used in a function or model to define its behavior. In machine learning, parameters are the internal variables of the model that are learned from the training data.

2. What is correlation?
Correlation is a statistical measure that describes the strength and direction of a relationship between two variables. It ranges from -1 to 1, where 1 indicates a perfect positive correlation, -1 indicates a perfect negative correlation, and 0 indicates no correlation.

3. What does negative correlation mean?
Negative correlation means that as one variable increases, the other variable tends to decrease. It is represented by a correlation coefficient less than 0.

4. Define Machine Learning.
Machine Learning is a field of artificial intelligence that focuses on developing algorithms and models that enable computers to learn from and make predictions or decisions based on data.

5. What are the main components in Machine Learning?
The main components in Machine Learning are: Data, Features, Model, Training, Evaluation, and Prediction.

6. How does loss value help in determining whether the model is good or not?
The loss value measures the difference between the predicted output and the actual output. A lower loss value indicates a better model, as it means the model's predictions are closer to the actual values.

7. What are continuous and categorical variables?
Continuous variables are numerical variables that can take any value within a range, such as height or weight. Categorical variables are variables that represent categories or groups, such as gender or color.

8. How do we handle categorical variables in Machine Learning? What are the common techniques?
Categorical variables can be handled using techniques such as One-Hot Encoding, Label Encoding, and Binary Encoding. These techniques convert categorical data into numerical data that can be used by machine learning algorithms.

9. What do you mean by training and testing a dataset?
Training a dataset involves using a portion of the data to train the machine learning model, while testing a dataset involves using another portion of the data to evaluate the model's performance.

10. What is sklearn.preprocessing?
sklearn.preprocessing is a module in the scikit-learn library that provides various preprocessing techniques, such as scaling, encoding, and normalization, to prepare data for machine learning models.

11. What is a Test set?
A Test set is a subset of the dataset that is used to evaluate the performance of a trained machine learning model. It is not used during the training process.

12. How do we split data for model fitting (training and testing) in Python?
In Python, data can be split for model fitting using the train_test_split function from the scikit-learn library. This function splits the data into training and testing sets.

13. How do you approach a Machine Learning problem?
Approaching a Machine Learning problem involves several steps: Understanding the problem, Collecting and preparing data, Exploring and analyzing data, Selecting and training a model, Evaluating the model, and Making predictions.

14. Why do we have to perform EDA before fitting a model to the data?
Exploratory Data Analysis (EDA) helps in understanding the data, identifying patterns, detecting anomalies, and selecting relevant features. It is an essential step before fitting a model to ensure better model performance.

15. What is correlation?
Correlation is a statistical measure that describes the strength and direction of a relationship between two variables. It ranges from -1 to 1, where 1 indicates a perfect positive correlation, -1 indicates a perfect negative correlation, and 0 indicates no correlation.

16. What does negative correlation mean?
Negative correlation means that as one variable increases, the other variable tends to decrease. It is represented by a correlation coefficient less than 0.

17. How can you find correlation between variables in Python?
In Python, correlation between variables can be found using the corr() method from the pandas library or the pearsonr() function from the scipy.stats module.

18. What is causation? Explain difference between correlation and causation with an example.
Causation indicates a cause-and-effect relationship between two variables, where one variable directly affects the other. Correlation, on the other hand, only indicates a relationship between variables without implying causation. For example, ice cream sales and drowning incidents may be correlated, but eating ice cream does not cause drowning.

19. What is an Optimizer? What are different types of optimizers? Explain each with an example.
An Optimizer is an algorithm used to minimize the loss function and update the model's parameters during training. Different types of optimizers include: Gradient Descent, Stochastic Gradient Descent (SGD), Adam, RMSprop, and Adagrad. Each optimizer has its own update rules and learning rate adjustments.

20. What is sklearn.linear_model?
sklearn.linear_model is a module in the scikit-learn library that provides various linear models for regression and classification tasks, such as Linear Regression, Logistic Regression, and Ridge Regression.

21. What does model.fit() do? What arguments must be given?
model.fit() trains the machine learning model using the provided training data. The arguments that must be given are the input features (X) and the target labels (y).

22. What does model.predict() do? What arguments must be given?
model.predict() makes predictions using the trained model on new input data. The argument that must be given is the input features (X) for which predictions are to be made.

23. What are continuous and categorical variables?
Continuous variables are numerical variables that can take any value within a range, such as height or weight. Categorical variables are variables that represent categories or groups, such as gender or color.

24. What is feature scaling? How does it help in Machine Learning?
Feature scaling is the process of normalizing or standardizing the range of features in the data. It helps in machine learning by ensuring that all features contribute equally to the model and improving the convergence of optimization algorithms.

25. How do we perform scaling in Python?
In Python, scaling can be performed using the StandardScaler or MinMaxScaler from the sklearn.preprocessing module.

26. What is sklearn.preprocessing?
sklearn.preprocessing is a module in the scikit-learn library that provides various preprocessing techniques, such as scaling, encoding, and normalization, to prepare data for machine learning models.

27. How do we split data for model fitting (training and testing) in Python?
In Python, data can be split for model fitting using the train_test_split function from the scikit-learn library. This function splits the data into training and testing sets.

28. Explain data encoding?
Data encoding is the process of converting categorical data into numerical data that can be used by machine learning algorithms. Common techniques include One-Hot Encoding, Label Encoding, and Binary Encoding.
